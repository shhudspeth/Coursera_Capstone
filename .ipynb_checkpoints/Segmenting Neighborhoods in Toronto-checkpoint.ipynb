# %% [markdown]
# ## Segmenting Neighborhoods in Toronto Notebook

# %%
import pandas as pd

# %%
! wget -O postalcodesT https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Out:
# --2020-04-10 14:18:47--  https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Resolving en.wikipedia.org... 2620:0:863:ed1a::1, 198.35.26.96
# Connecting to en.wikipedia.org|2620:0:863:ed1a::1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52229 (51K) [text/html]
# Saving to: 'postalcodesT'
#
# postalcodesT        100%[===================>]  51.00K  --.-KB/s    in 0.04s
#
# 2020-04-10 14:18:47 (1.14 MB/s) - 'postalcodesT' saved [52229/52229]

# %%
# read wget file. I got lucky as I saw it was a list and put[0] after and found that it read it all. 
df = pd.read_html('postalcodesT')[0]
df
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW / The Queensway West / South of Bloo...
# 179                                                NaN
#
# [180 rows x 3 columns]

# %%
# find all the Boroughs who do not have a name and drop them
not_assigned_index = df.index[df['Borough'] == 'Not assigned']
df.drop(index=not_assigned_index, inplace=True)

# %%
# There are no Neighborhoods who have Null values
df[df['Neighborhood'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Postal code, Borough, Neighborhood]
# Index: []

# %%
#Reset Dataframe Index for clarity's sake
df = df.reset_index(drop=True)
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park / Harbourfront
# 3                    Lawrence Manor / Lawrence Heights
# 4         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway / Montgomery Road / Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# 101  Old Mill South / King's Mill Park / Sunnylea /...
# 102  Mimico NW / The Queensway West / South of Bloo...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # End Part One

# %% [markdown]
# # PART TWO

# %%
# !wget http://cocl.us/Geospatial_data
# Out:
# --2020-04-10 14:36:11--  http://cocl.us/Geospatial_data
# Resolving cocl.us... 169.48.113.194, 158.85.108.83, 158.85.108.86
# Connecting to cocl.us|169.48.113.194|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-04-10 14:36:11--  https://cocl.us/Geospatial_data
# Connecting to cocl.us|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-04-10 14:36:13--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com... 107.152.25.197, 107.152.24.197
# Connecting to ibm.box.com|107.152.25.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-04-10 14:36:13--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-04-10 14:36:13--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com... 107.152.25.211, 107.152.24.211
# Connecting to ibm.ent.box.com|107.152.25.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!PhtvHEtltzPgtp9sUx-4B7FeaB3CC6BcFwJNprSIKfoedxRC_RuIDi1fDfz4C5b4lcz774oYFzQ_r9C4gfncTiAyKTuwEnK8ZaFag3FNDtTHGDfjHUS0haSno56dMYtFN6eZKgxRmA3gDUNbFEfJmPSzX4rCQ5UJIBDY4qUXcl0FfcrnU7dDKRwyv4WYXUsr0v7G6jsRJD_hsgGloWCq5k6CmV1OO548HL8VWOMqSSzzXOCCYSaUoljQTbZvFEr3Aj2aVtF-dZJFuTGgwP2W0v8ZQ4eWDFkFFx_xcoDJqeV6a2avdYo78kJJ2L20t38elvDMeQ7
MeQ7zRdPQzEastqMVYvPDTdPcHy1e8AjGtlti_bT2A-Q9DKfuXmzAHMvydCbpGGc61OyZtr83r9dsAbh5N5OwNmUDyKW85aN8h7Q4UpaUbx84SKl-LefBTQF4gRi4I23AqrrOXAeqaKcdkaDgslf72a5rWaZgNEBn2OPPLZ4tuDPb0Ed6TLnmIH570NQEEH-G4f0fXf7qZIbBZ435cyaX9q35sybIWrifS1gA8idk2uBLnd25iSGA3O8cT2Flp6KqDEJwXRzxRm0U-ZUJyCb3bgRsA4kWzD8dOi7OxRnWKDnnCG2NR1fHYQ-4rJlRhkItgI5eMsi2Vk_o5GRvoCGcHe7nGQ0_rsFDvlm_AsUHwXefDgSk-q2bkN8Z6V8svO8TEI9HM9TnxWyASEv9O6ZL2v33JCA1fngjCk9ev5XjbZlqyO17rHLk5Go_ed2sV_Y1a-cU70_ngCiMtq28oM3qVNYXfu1mLHulcm-i2DlKC99_jAzvvplis7XETwaAy_l7oDjm8_Tm4ZtiYzwcwN9_81ESHu5rB-Ibxpq4aIXsBr6q5-vCrxAJYdLgAtXqlc3C7heX2rnANnMuAlSo8dWYACykbRoas4sgxdKGukJqiiwkuL3zDtlhiRAf9ubrbTuF66iHRel6odswO1Ljohvr2Y0zQyWWk5_SRaC5FSNI4r60YLtfPvi5t7bjGKkL4KLHY_qbWIjC3IpKSMvfs4PItv9O-LpKVD4s43XcsSbHc-t2cgZJDwEIFp9K5aqR-Q0_zfmPKiDJklveyEoQYQ9c3GTHlRW3AgeA1zn9AFolaSASqVCKXS8METpG0HFLjkrPuuZ1_YLYtJCYsxx4Xl4T-xKYYVK3D5AI2YdHpvB0fMESB-qCBAE3B9Nq0YQBJA1WaTYQ1Sd5Qy0zWl9-QGrWR7Pb8ZkJntkEnuQB28u-dghiwKu55-wjr4VDyG9i5vBmNqbO2WVp43x712trcqM7ZSgX72QtKIAGn2q9zdf71ATRc_ZXBdScenosX-AZlDbiZktr-JTw7ydXN-dxeH__2ijAjyHdKDV636xAOiHPMKejOU7M4P_BPAtwoesGbF9V40_di8x3y_zpwXm0_k2vujDV6tBiJYSY7ey6VGzb/download
# Resolving public.boxcloud.com... 107.152.25.200
# Connecting to public.boxcloud.com|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: 'Geospatial_data'
#
# Geospatial_data     100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2020-04-10 14:36:14 (52.0 MB/s) - 'Geospatial_data' saved [2891/2891]

# %%
geo_df = pd.read_csv('Geospatial_data')

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
toronto_neighborhoods = pd.merge(geo_df, df, right_on='Postal code', left_on='Postal Code', how='right')

# %%
toronto_neighborhoods = toronto_neighborhoods[['Postal Code', 'Borough', 'Neighborhood', 'Latitude', 'Longitude']]

# %%
toronto_neighborhoods
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                      Malvern / Rouge  43.806686 -79.194353
# 1             Rouge Hill / Port Union / Highland Creek  43.784535 -79.160497
# 2                  Guildwood / Morningside / West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village / St. Phillips / Martin Grov...  43.688905 -79.554724
# 101  South Steeles / Silverstone / Humbergate / Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]
