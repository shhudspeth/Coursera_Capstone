# %% [markdown]
# ## MOST POPULAR RESTAURANTS PER CLUSTER

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Alameda_Hospital_Venues.csv
# Category:Hospitals_in_the_San_Francisco_Bay_Area
# FOOD&HEALTHWorkersBAYAREA.csv
# Geospatial_data
# Hospital Name and Location Scrape Notebooks.ipynb
# Hospital_locations
# Hospital_locations.csv
# IBM Coursera Capstone.ipynb
# Introduction and Business Project --IBM COURSERA PROJECT
# README.md
# Segmenting Neighborhoods in Toronto.ipynb
# Untitled.ipynb
# bay_area_geo.cvs
# clustered_hospitals_sf.html
# food_Workers_dist_sf.html
# food_Workers_dist_sf_and_hospitals.html
# food_Workers_dist_sf_and_hospitals_red.html
# food_Workers_percentofworkforce+hospitals_sf.html
# food_health_workers.csv
# health_Workers_dist_sf.html
# health_Workers_percentofworkforce+hospitals_sf.html
# hospital_venues_ratings.csv
# hospitals_sf.html
# hospitals_sf.png
# postalcodesT

# %%
df_venues_ratings = pd.read_csv('hospital_venues_ratings.csv')

# %%
df_venues_ratings
# Out:
#       Unnamed: 0                                           Hospital  \
# 0              0                        Agnews Developmental Center
# 1              1                        Agnews Developmental Center
# 2              2                        Agnews Developmental Center
# 3              3                        Agnews Developmental Center
# 4              4                        Agnews Developmental Center
# ...          ...                                                ...
# 1555        1555  University of California, San Francisco Fetal ...
# 1556        1556  University of California, San Francisco Fetal ...
# 1557        1557  University of California, San Francisco Fetal ...
# 1558        1558  University of California, San Francisco Fetal ...
# 1559        1559  University of California, San Francisco Fetal ...
#
#       Hospital Latitude  Hospital Longitude     Venue City  \
# 0             37.394663         -121.959125    Santa Clara
# 1             37.394663         -121.959125    Santa Clara
# 2             37.394663         -121.959125    Santa Clara
# 3             37.394663         -121.959125    Santa Clara
# 4             37.394663         -121.959125    Santa Clara
# ...                 ...                 ...            ...
# 1555          37.765567         -122.389776  San Francisco
# 1556          37.765567         -122.389776  San Francisco
# 1557          37.765567         -122.389776  San Francisco
# 1558          37.765567         -122.389776  San Francisco
# 1559          37.765567         -122.389776  San Francisco
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0              Premier Pizza       37.394546      -121.946428
# 1       Great Indian Cuisine       37.394322      -121.959752
# 2     Easterly Hunan Cuisine       37.394570      -121.945728
# 3         Jersey Mike's Subs       37.394932      -121.945820
# 4          Logan's Big Dawgs       37.394181      -121.959764
# ...                      ...             ...              ...
# 1555          Hard Knox Cafe       37.757564      -122.388313
# 1556           Casey’s Pizza       37.773783      -122.391495
# 1557               Sunflower       37.762609      -122.397538
# 1558  Esposto's Delicatessen       37.766888      -122.393159
# 1559  Tadu Ethiopian Kitchen       37.773950      -122.391543
#
#                        Venue Category  \
# 0                         Pizza Place
# 1                   Indian Restaurant
# 2                  Chinese Restaurant
# 3                      Sandwich Place
# 4                          Food Truck
# ...                               ...
# 1555  Southern / Soul Food Restaurant
# 1556                      Pizza Place
# 1557            Vietnamese Restaurant
# 1558                    Deli / Bodega
# 1559             Ethiopian Restaurant
#
#                                               yelp_link           rating  \
# 0     https://www.yelp.com/biz/premier-pizza-santa-c...  3.5 star rating
# 1     https://www.yelp.com/biz/great-indian-cuisine-...    4 star rating
# 2     https://www.yelp.com/biz/easterly-hunan-cuisin...  3.5 star rating
# 3     https://www.yelp.com/biz/jersey-mikes-subs-san...  3.5 star rating
# 4     https://www.yelp.com/biz/logans-big-dawgs-sant...              4.5
# ...                                                 ...              ...
# 1555  https://www.yelp.com/biz/hard-knox-cafe-san-fr...    4 star rating
# 1556  https://www.yelp.com/biz/casey’s-pizza-san-fra...                0
# 1557   https://www.yelp.com/biz/sunflower-san-francisco                0
# 1558  https://www.yelp.com/biz/espostos-delicatessen...    4 star rating
# 1559  https://www.yelp.com/biz/tadu-ethiopian-kitche...  4.5 star rating
#
#            reviews
# 0      360 reviews
# 1      488 reviews
# 2      140 reviews
# 3      214 reviews
# 4             117
# ...            ...
# 1555  2155 reviews
# 1556             0
# 1557             0
# 1558    68 reviews
# 1559   666 reviews
#
# [1560 rows x 12 columns]

# %%
df_venues_ratings['rating'] = df_venues_ratings['rating'].str.replace('star rating', '')

# %%
df_venues_ratings['reviews'] = df_venues_ratings['reviews'].str.replace('reviews', '')
df_venues_ratings['reviews'] = df_venues_ratings['reviews'].str.replace('\[\]', '0')
# Out:
# /Users/shhuds/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/shhuds/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_venues_ratings = df_venues_ratings[df_venues_ratings['rating'] != "[]"].reset_index()
# Out:
# /Users/shhuds/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df_venues_ratings[df_venues_ratings['reviews'] == "[]"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Hospital, Hospital Latitude, Hospital Longitude, Venue City, Venue, Venue Latitude, Venue Longitude, Venue Category, yelp_link, rating, reviews]
# Index: []

# %%
df_venues_ratings['rating']  = df_venues_ratings['rating'].astype(float)
# Out:
# /Users/shhuds/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_venues_ratings.drop(columns=['index', 'Unnamed: 0'], inplace=True)
df_venues_ratings
# Out:
#                                                Hospital  Hospital Latitude  \
# 0                           Agnews Developmental Center          37.394663
# 1                           Agnews Developmental Center          37.394663
# 2                           Agnews Developmental Center          37.394663
# 3                           Agnews Developmental Center          37.394663
# 4                           Agnews Developmental Center          37.394663
# ...                                                 ...                ...
# 1276  University of California, San Francisco Fetal ...          37.765567
# 1277  University of California, San Francisco Fetal ...          37.765567
# 1278  University of California, San Francisco Fetal ...          37.765567
# 1279  University of California, San Francisco Fetal ...          37.765567
# 1280  University of California, San Francisco Fetal ...          37.765567
#
#       Hospital Longitude     Venue City                   Venue  \
# 0            -121.959125    Santa Clara           Premier Pizza
# 1            -121.959125    Santa Clara    Great Indian Cuisine
# 2            -121.959125    Santa Clara  Easterly Hunan Cuisine
# 3            -121.959125    Santa Clara      Jersey Mike's Subs
# 4            -121.959125    Santa Clara       Logan's Big Dawgs
# ...                  ...            ...                     ...
# 1276         -122.389776  San Francisco          Hard Knox Cafe
# 1277         -122.389776  San Francisco           Casey’s Pizza
# 1278         -122.389776  San Francisco               Sunflower
# 1279         -122.389776  San Francisco  Esposto's Delicatessen
# 1280         -122.389776  San Francisco  Tadu Ethiopian Kitchen
#
#       Venue Latitude  Venue Longitude                   Venue Category  \
# 0          37.394546      -121.946428                      Pizza Place
# 1          37.394322      -121.959752                Indian Restaurant
# 2          37.394570      -121.945728               Chinese Restaurant
# 3          37.394932      -121.945820                   Sandwich Place
# 4          37.394181      -121.959764                       Food Truck
# ...              ...              ...                              ...
# 1276       37.757564      -122.388313  Southern / Soul Food Restaurant
# 1277       37.773783      -122.391495                      Pizza Place
# 1278       37.762609      -122.397538            Vietnamese Restaurant
# 1279       37.766888      -122.393159                    Deli / Bodega
# 1280       37.773950      -122.391543             Ethiopian Restaurant
#
#                                               yelp_link  rating reviews
# 0     https://www.yelp.com/biz/premier-pizza-santa-c...     3.5    360
# 1     https://www.yelp.com/biz/great-indian-cuisine-...     4.0    488
# 2     https://www.yelp.com/biz/easterly-hunan-cuisin...     3.5    140
# 3     https://www.yelp.com/biz/jersey-mikes-subs-san...     3.5    214
# 4     https://www.yelp.com/biz/logans-big-dawgs-sant...     4.5    117
# ...                                                 ...     ...     ...
# 1276  https://www.yelp.com/biz/hard-knox-cafe-san-fr...     4.0   2155
# 1277  https://www.yelp.com/biz/casey’s-pizza-san-fra...     0.0       0
# 1278   https://www.yelp.com/biz/sunflower-san-francisco     0.0       0
# 1279  https://www.yelp.com/biz/espostos-delicatessen...     4.0     68
# 1280  https://www.yelp.com/biz/tadu-ethiopian-kitche...     4.5    666
#
# [1281 rows x 11 columns]

# %% [markdown]
# ## most highly rated venues

# %%
rated_venues_types = df_venues_ratings.groupby(['Hospital', 'Venue Category',])['rating'].mean().to_frame()

# %%
rated_venues_types
# Out:
#                                                                 rating
# Hospital                               Venue Category
# Adventist Health Clear Lake            American Restaurant        3.75
#                                        Café                       4.50
#                                        Donut Shop                 4.50
#                                        Fast Food Restaurant       2.00
#                                        Mexican Restaurant         4.50
# ...                                                                ...
# Veterans Home of California Yountville Mexican Restaurant         3.50
#                                        New American Restaurant    4.00
#                                        Pizza Place                4.00
#                                        Restaurant                 4.50
#                                        Spanish Restaurant         4.00
#
# [891 rows x 1 columns]

# %%
rated_venues = df_venues_ratings.groupby(['Hospital', 'Venue', 'Venue Category', 'reviews'])['rating'].mean().to_frame()

# %%
rated_v = df_venues_ratings[['Hospital', 'Venue', 'Venue Category', 'reviews', 'rating']]

# %%
rated_v = rated_v[rated_v['rating']>4]
rated_v
# Out:
#                                                Hospital  \
# 4                           Agnews Developmental Center
# 9                           Agnews Developmental Center
# 20                          Agnews Developmental Center
# 28                                     Alameda Hospital
# 32                                     Alameda Hospital
# ...                                                 ...
# 1262  University of California, San Francisco Fetal ...
# 1265  University of California, San Francisco Fetal ...
# 1266  University of California, San Francisco Fetal ...
# 1271  University of California, San Francisco Fetal ...
# 1280  University of California, San Francisco Fetal ...
#
#                                Venue        Venue Category reviews  rating
# 4                  Logan's Big Dawgs            Food Truck    117      4.5
# 9                 Chicken Meets Rice            Restaurant    665      4.5
# 20              Big Ed's Buzzard BBQ             BBQ Joint    298      4.5
# 28              Doggy-Style Hot Dogs         Hot Dog Joint    335      4.5
# 32                           Utzutzu      Sushi Restaurant     74      4.5
# ...                              ...                   ...     ...     ...
# 1262                 Chez Maman East     French Restaurant   2074      4.5
# 1265                     Parker Cafe                  Café    182      4.5
# 1266                       Wooly Pig        Sandwich Place    657      4.5
# 1271  Marcella's Lasagneria & Cucina    Italian Restaurant    374      4.5
# 1280          Tadu Ethiopian Kitchen  Ethiopian Restaurant    666      4.5
#
# [223 rows x 5 columns]

# %%
rated_venues = rated_venues[rated_venues['rating']>=3.5]
rated_venues
# Out:
#                                                                                                 rating
# Hospital                               Venue                   Venue Category          reviews
# Adventist Health Clear Lake            Cactus Grill            Mexican Restaurant      110         4.5
#                                        Castle Donuts           Donut Shop              18          4.5
#                                        Catfish Coffee House    Café                    92          4.5
#                                        Kour Thai Restaurant    Restaurant              84          4.0
#                                        Main Street Bar & Grill American Restaurant     164         3.5
# ...                                                                                                ...
# Veterans Home of California Yountville Redd Wood               Pizza Place             743         4.0
#                                        Southside Cafe          Café                    99          4.5
#                                        The French Laundry      French Restaurant       2584        4.5
#                                        The Habit Burger Grill  Burger Joint            513         3.5
#                                        ad hoc                  New American Restaurant 2844        4.0
#
# [1119 rows x 1 columns]

# %%
no = 1
hospit_venues = {}
list_of_hosp = [rated_venues.index.get_level_values(0).unique()]

for x in range(len(rated_venues.index.get_level_values(0).unique()[0])):
    hospit_venues[rated_venues.index.get_level_values(0).unique()[x]] = rated_venues.loc[rated_venues.index.get_level_values(0).unique()[x]]

# %%
list_of_df = []
for x in hospit_venues.keys():
    list_of_df.append(pd.DataFrame(hospit_venues[x]))

# %%
hospit_venues.keys()
# Out:
# dict_keys(['Adventist Health Clear Lake', 'Adventist Health St. Helena', 'Agnews Developmental Center', 'Alameda Hospital', 'Alcatraz Hospital', 'Alta Bates Summit Medical Center', 'Brookside Hospital', 'California Pacific Medical Center', 'Childrens Hospital Oakland', 'Davies Medical Center', 'Doctors Medical Center San Pablo Campus', 'El Camino Hospital', 'Friends of Laguna Honda Hospital', 'Good Samaritan Hospital (San Jose)', 'Highland Hospital (Oakland, California)', 'John George Psychiatric Pavilion', 'John Muir Medical Center (Concord Campus)', 'John Muir Medical Center (Walnut Creek Campus)', 'Kaiser Richmond Field Hospital', 'Langley Porter Psychiatric Institute', 'Letterman Army Hospital', 'Marys Help Hospital', 'Napa State Hospital', 'Naval Hospital Oakland', 'OConnor Hospital', 'Oakland Medical Center', 'Pacific Dispensary for Women and Children'])

# %%
df_AdventistHealthStHelena = list_of_df[1]
df_AdventistHealthStHelena
# Out:
#                                                              rating
# Venue                       Venue Category          reviews
# Acacia House                Restaurant              140         4.0
# Archetype                   New American Restaurant 631         4.0
# Cook St. Helena             Italian Restaurant      412         4.0
# Evangeline                  Bistro                  385         4.0
# Gillwoods Cafe              Breakfast Spot          278         4.0
# Go Fish                     Sushi Restaurant        164         4.0
# Goose & Gander              American Restaurant     959         4.0
# Gott's Roadside             Burger Joint            2016        4.0
# Himalayan Sherpa Kitchen    Restaurant              317         4.5
# Market                      American Restaurant     712         4.0
# Pizzeria Tra Vigne          Pizza Place             517         4.0
# St. Helena Bistro           American Restaurant     135         4.0
# The Charter Oak             New American Restaurant 340         4.0
# The Grill at Meadowood      American Restaurant     200         4.5
# The Model Bakery            Bakery                  409         4.0
# The Restaurant at Meadowood New American Restaurant 200         4.5
# W F Giugni & Son Grocery Co Sandwich Place          323         4.5

# %%
df_AdventistHealthClearLake = list_of_df[0]
df_AdventistHealthClearLake
# Out:
#                                                      rating
# Venue                   Venue Category      reviews
# Cactus Grill            Mexican Restaurant  110         4.5
# Castle Donuts           Donut Shop          18          4.5
# Catfish Coffee House    Café                92          4.5
# Kour Thai Restaurant    Restaurant          84          4.0
# Main Street Bar & Grill American Restaurant 164         3.5
# Pogo's Pizza Co.        Pizza Place         8           3.5
# The Spot                American Restaurant 271         4.0

# %%
df_agnews = list_of_df[2]
df_agnews
# Out:
#                                                                     rating
# Venue                                Venue Category        reviews
# Amakai Japanese Cuisine              Japanese Restaurant   195         4.0
# Athena Grill & Catering              Greek Restaurant      1533        4.0
# Big Ed's Buzzard BBQ                 BBQ Joint             298         4.5
# Birk's Restaurant                    Steakhouse            795         3.5
# Bourbon Steak & Pub                  Steakhouse            378         3.5
# Chicken Meets Rice                   Restaurant            665         4.5
# Easterly Hunan Cuisine               Chinese Restaurant    140         3.5
# Feride’s Bakery                      Bakery                251         4.0
# Flemings Prime Steakhouse & Wine Bar Steakhouse            447         4.0
# Great Indian Cuisine                 Indian Restaurant     488         4.0
# IGrill Kebabs and Biryani            Indian Restaurant     277         4.0
# In-N-Out Burger                      Fast Food Restaurant  494         4.0
# Jersey Mike's Subs                   Sandwich Place        214         3.5
# Logan's Big Dawgs                    Food Truck            117         4.5
# Mikayla's Cafe                       Breakfast Spot        714         3.5
# New Ca Mau Restaurant                Vietnamese Restaurant 271         3.5
# Pedro's Restaurant & Cantina         Mexican Restaurant    1235        3.5
# Phở Khang                            Vietnamese Restaurant 279         3.5
# Premier Pizza                        Pizza Place           360         3.5
# Prime Restaurant                     Restaurant            67          3.5
# Specialty’s Café & Bakery            Bakery                573         3.5

# %%
df_hos_clusters = pd.read_csv('Hospital_CLusters_and_venues.csv')

# %%
df_hos_clusters
# Out:
#                                                  name        lat         lng  \
# 0                         Agnews Developmental Center  37.394663 -121.959125
# 1                                    Alameda Hospital  37.762677 -122.254155
# 2                                   Alcatraz Hospital  37.785467 -122.439318
# 3                    Alta Bates Summit Medical Center  37.821648 -122.262967
# 4                                  Brookside Hospital  37.953721 -122.337278
# 5             Doctors Medical Center San Pablo Campus  37.953091 -122.336511
# 6                                  El Camino Hospital  37.368848 -122.080185
# 7                  Good Samaritan Hospital (San Jose)  37.252044 -121.946530
# 8                    John George Psychiatric Pavilion  37.710840 -122.120215
# 9           John Muir Medical Center (Concord Campus)  37.982900 -122.033756
# 10     John Muir Medical Center (Walnut Creek Campus)  37.912963 -122.041215
# 11                     Kaiser Richmond Field Hospital  37.937188 -122.360556
# 12                                Marys Help Hospital  37.679670 -122.474224
# 13                             Naval Hospital Oakland  37.765105 -122.149974
# 14                                   OConnor Hospital  37.327557 -121.939001
# 24        Japanese Restaurant         Sandwich Place
# 25      Vietnamese Restaurant             Taco Place
# 26         Italian Restaurant                 Bakery
# 27                Pizza Place          Deli / Bodega
# 28         Mexican Restaurant            Pizza Place
# 29                 Donut Shop              Gastropub
# 30                   Pet Café             Bagel Shop
# 31                Salad Place       Ramen Restaurant
# 32                Salad Place                 Bakery
# 33                      Diner             Donut Shop
# 34    New American Restaurant     Falafel Restaurant
# 35             Breakfast Spot    Hawaiian Restaurant
# 36                  BBQ Joint    Hawaiian Restaurant
# 37           Sushi Restaurant      Indian Restaurant
# 38                       Café     Seafood Restaurant
# 39        American Restaurant         Sandwich Place
# 40             Sandwich Place     Italian Restaurant
# 41    New American Restaurant     Dim Sum Restaurant
# 42         Mexican Restaurant    Peruvian Restaurant
# 43         Mexican Restaurant    Peruvian Restaurant
# 44         Seafood Restaurant   Ethiopian Restaurant
# 45                Salad Place      Korean Restaurant
# 46        Peruvian Restaurant     Mexican Restaurant
#
#         9th Most Common Venue       10th Most Common Venue
# 0         Hawaiian Restaurant          Japanese Restaurant
# 1               Hot Dog Joint           Italian Restaurant
# 2          Italian Restaurant           Mexican Restaurant
# 3                    Pet Café    Latin American Restaurant
# 4           Korean Restaurant           Seafood Restaurant
# 5           Korean Restaurant           Seafood Restaurant
# 6                Burger Joint      New American Restaurant
# 7                  Donut Shop                  Wings Joint
# 8                 Pizza Place          Dumpling Restaurant
# 9                       Diner                Deli / Bodega
# 10                       Café                   Restaurant
# 11              Deli / Bodega                  Pizza Place
# 12         Mexican Restaurant             Ramen Restaurant
# 13         Mexican Restaurant           Seafood Restaurant
# 14        Dumpling Restaurant            Korean Restaurant
# 15           Tapas Restaurant                Deli / Bodega
# 16         Italian Restaurant            Korean Restaurant
# 17                  BBQ Joint                   Steakhouse
# 18               Burger Joint                       Bistro
# 19             Sandwich Place                         Food
# 20      Vietnamese Restaurant           Italian Restaurant
# 21         Burmese Restaurant         Ethiopian Restaurant
# 22                  Gastropub           Italian Restaurant
# 23    North Indian Restaurant                        Diner
# 24  Cajun / Creole Restaurant                   Food Court
# 25                      Diner                   Donut Shop
# 26                 Donut Shop                       Bistro
# 27         Mexican Restaurant         Brazilian Restaurant
# 28   Mediterranean Restaurant             Ramen Restaurant
# 29             Breakfast Spot     Mediterranean Restaurant
# 30                 Restaurant    Latin American Restaurant
# 31         Dim Sum Restaurant                        Diner
# 32          Indian Restaurant     Mediterranean Restaurant
# 33        Dumpling Restaurant  Eastern European Restaurant
# 34              Deli / Bodega                 Burger Joint
# 35              Deli / Bodega           Mexican Restaurant
# 36         Chinese Restaurant        Portuguese Restaurant
# 37              Deli / Bodega         Caribbean Restaurant
# 38              Deli / Bodega      New American Restaurant
# 39                 Food Truck        Vietnamese Restaurant
# 40  Latin American Restaurant          Japanese Restaurant
# 41   Mediterranean Restaurant            Korean Restaurant
# 42   Mediterranean Restaurant          Dumpling Restaurant
# 43   Mediterranean Restaurant          Dumpling Restaurant
# 44              Deli / Bodega          Peruvian Restaurant
# 45      Vietnamese Restaurant                       Bakery
# Alta Bates Summit Medical Center                   American Restaurant   Mexican Restaurant       Korean Restaurant                           2
# Brookside Hospital                                 Mexican Restaurant    Food Truck               American Restaurant                         2
# Doctors Medical Center San Pablo Campus            Food Truck            American Restaurant      Mexican Restaurant                          2
# Good Samaritan Hospital (San Jose)                 Sandwich Place        Mexican Restaurant       Burger Joint                                2
# Richmond Medical Center                            American Restaurant   Vietnamese Restaurant    Mexican Restaurant                          2
# John George Psychiatric Pavilion                   Mexican Restaurant    Vietnamese Restaurant    American Restaurant                         2
# Kaiser Richmond Field Hospital                     Mexican Restaurant    American Restaurant      Thai Restaurant                             2
# OConnor Hospital                                   American Restaurant   Pizza Place              Thai Restaurant                             2
# Oakland Medical Center                             Korean Restaurant     American Restaurant      Mexican Restaurant                          2
# Vacaville Medical Center                           Mexican Restaurant    Burger Joint             Diner                                       2
# Queen of the Valley Medical Center                 Mexican Restaurant    Burger Joint             American Restaurant                         2
# John Muir Medical Center (Concord Campus)          Mexican Restaurant    Mediterranean Restaurant Chinese Restaurant                          2
# Letterman Army Hospital                            Burger Joint          New American Restaurant  Food Truck                                  3
# Adventist Health St. Helena                        American Restaurant   New American Restaurant  Restaurant                                  4
# Veterans Home of California Yountville             American Restaurant   New American Restaurant  Italian Restaurant                          4

# %%
most_common = df_hos_clusters[['3rd Most Common Venue']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-197-94e03da9dbdf> in <module>
#       1 most_common = df_hos_clusters[['1st Most Common Venue', '2nd Most Common Venue', \
# ----> 2                          '3rd Most Common Venue']].plot(kind='bar')
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
most_common = df_hos_clusters.groupby(['1st Most Common Venue'])['1st Most Common Venue'].count()
most_common.to_frame()
most_common.columns = ['Type', 'Frequency']
# most_common['Cluster_Labels'] = most_common.index.get_level_values(1)
most_common.to_frame().plot(kind='bar')
plt.tight_layout()
plt.savefig('MostCommon.png')

# %%
third_common = df_hos_clusters.groupby(['3rd Most Common Venue'])['3rd Most Common Venue'].count()
third_common.to_frame().plot(kind='bar').savefig("3rd Most Common")

# %%
third_common
# Out:
# 3rd Most Common Venue
# American Restaurant              3
# Breakfast Spot                   3
# Burger Joint                     4
# Café                             1
# Chinese Restaurant               2
# Diner                            1
# Donut Shop                       1
# Food Truck                       1
# Indian Restaurant                2
# Italian Restaurant               3
# Korean Restaurant                2
# Mediterranean Restaurant         1
# Mexican Restaurant               6
# Middle Eastern Restaurant        1
# New American Restaurant          2
# Pizza Place                      2
# Poke Place                       1
# Portuguese Restaurant            1
# Restaurant                       1
# Sandwich Place                   1
# Sushi Restaurant                 3
# Thai Restaurant                  2
# Vegetarian / Vegan Restaurant    1
# Vietnamese Restaurant            2
# Name: 3rd Most Common Venue, dtype: int64

# %%
two_common = df_hos_clusters.groupby(['2nd Most Common Venue'])['2nd Most Common Venue'].count()
two_common.to_frame().plot(kind='bar')
# most_common['Cluster_Labels'] = most_common.index.get_level_values(1)

# %%
two_common
# Out:
# 2nd Most Common Venue
# American Restaurant         7
# BBQ Joint                   1
# Bakery                      4
# Breakfast Spot              2
# Burger Joint                3
# Café                        1
# Deli / Bodega               1
# Fast Food Restaurant        1
# Filipino Restaurant         1
# Food Truck                  2
# Japanese Restaurant         1
# Mediterranean Restaurant    1
# Mexican Restaurant          4
# New American Restaurant     3
# Pizza Place                 3
# Sandwich Place              5
# Steakhouse                  1
# Sushi Restaurant            4
# Vietnamese Restaurant       2
# Name: 2nd Most Common Venue, dtype: int64

# %%
most_common.index ^ two_common.index
# Out:
# Index(['Chinese Restaurant', 'Deli / Bodega', 'Filipino Restaurant',
#        'French Restaurant', 'Indian Restaurant', 'Italian Restaurant',
#        'Japanese Restaurant', 'Korean Restaurant', 'Mediterranean Restaurant',
#        'New American Restaurant', 'Seafood Restaurant', 'Steakhouse',
#        'Sushi Restaurant'],
#       dtype='object')

# %%
most_common.index ^ third_common.index
# Out:
# Index(['BBQ Joint', 'Bakery', 'Diner', 'Donut Shop', 'Fast Food Restaurant',
#        'French Restaurant', 'Mediterranean Restaurant',
#        'Middle Eastern Restaurant', 'New American Restaurant', 'Poke Place',
#        'Portuguese Restaurant', 'Restaurant', 'Seafood Restaurant',
#        'Sushi Restaurant', 'Thai Restaurant', 'Vegetarian / Vegan Restaurant'],
#       dtype='object')

# %%
top_three = pd.merge(most_common, two_common, how='outer', left_on=most_common.index, right_on=two_common.index)

# %%
top_three = 0

# %%
top_three = pd.merge(top_three, third_common, how='outer', left_on='key_0', right_on=third_common.index)
top_three.fillna(0)
# Out:
#                             key_0  1st Most Common Venue  \
# 0             American Restaurant                    6.0
# 1                       BBQ Joint                    1.0
# 2                          Bakery                    2.0
# 3                  Breakfast Spot                    1.0
# 4                    Burger Joint                    2.0
# 5                            Café                    7.0
# 6              Chinese Restaurant                    1.0
# 7            Fast Food Restaurant                    1.0
# 8                      Food Truck                    1.0
# 9               French Restaurant                    1.0
# 10              Indian Restaurant                    2.0
# 11             Italian Restaurant                    1.0
# 12              Korean Restaurant                    1.0
# 13             Mexican Restaurant                   13.0
# 14                    Pizza Place                    2.0
# 15                 Sandwich Place                    3.0
# 16             Seafood Restaurant                    1.0
# 17          Vietnamese Restaurant                    1.0
# 18                  Deli / Bodega                    0.0
# 19            Filipino Restaurant                    0.0
# 20            Japanese Restaurant                    0.0
# 21       Mediterranean Restaurant                    0.0
# 22        New American Restaurant                    0.0
# 23                     Steakhouse                    0.0
# 24               Sushi Restaurant                    0.0
# 25                          Diner                    0.0
# 26                     Donut Shop                    0.0
# 27      Middle Eastern Restaurant                    0.0
# 28                     Poke Place                    0.0
# 29          Portuguese Restaurant                    0.0
# 30                     Restaurant                    0.0
# 31                Thai Restaurant                    0.0
# 32  Vegetarian / Vegan Restaurant                    0.0
#
#     2nd Most Common Venue  3rd Most Common Venue_x  3rd Most Common Venue_y
# 0                     7.0                      3.0                      3.0
# 1                     1.0                      0.0                      0.0
# 2                     4.0                      0.0                      0.0
# 3                     2.0                      3.0                      3.0
# 4                     3.0                      4.0                      4.0
# 5                     1.0                      1.0                      1.0
# 6                     0.0                      2.0                      2.0
# 7                     1.0                      0.0                      0.0
# 8                     2.0                      1.0                      1.0
# 9                     0.0                      0.0                      0.0
# 10                    0.0                      2.0                      2.0
# 11                    0.0                      3.0                      3.0
# 12                    0.0                      2.0                      2.0
# 13                    4.0                      6.0                      6.0
# 14                    3.0                      2.0                      2.0
# 15                    5.0                      1.0                      1.0
# 16                    0.0                      0.0                      0.0
# 17                    2.0                      2.0                      2.0
# 18                    1.0                      0.0                      0.0
# 19                    1.0                      0.0                      0.0
# 20                    1.0                      0.0                      0.0
# 21                    1.0                      1.0                      1.0
# 22                    3.0                      2.0                      2.0
# 23                    1.0                      0.0                      0.0
# 24                    4.0                      3.0                      3.0
# 25                    0.0                      1.0                      1.0
# 26                    0.0                      1.0                      1.0
# 27                    0.0                      1.0                      1.0
# 28                    0.0                      1.0                      1.0
# 29                    0.0                      1.0                      1.0
# 30                    0.0                      1.0                      1.0
# 31                    0.0                      2.0                      2.0
# 32                    0.0                      1.0                      1.0

# %%
top_three.drop(columns=['3rd Most Common Venue_y'], inplace=True)

# %%
top_three.index.name= 'Venue Categories'

# %%
 top_three = top_three.set_index('Venue Categories').fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-69fb634bfd6a> in <module>
# ----> 1 top_three = top_three.set_index('Venue Categories').fillna(0)
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Venue Categories'] are in the columns"

# %%
ax = top_three.plot(kind='bar', width=.8, figsize=(12, 8), title='MOST COMMON VENUES')
fig = ax.get_figure()
fig.savefig('Top Three Venue Categories Bar Chart.png')
fig

# %%
import seaborn as sns
sns.set(style="whitegrid")

ax = sns.barplot(x=most_common.index.names[0], hue='Cluster_Labels', data=df_hos_clusters)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-e784d70aaed2> in <module>
#       2 sns.set(style="whitegrid")
#       3
# ----> 4 ax = sns.barplot(x=most_common.index.names[0], hue='Cluster_Labels', data=df_hos_clusters)
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
#    1614         self.establish_variables(x, y, hue, data, orient,
# -> 1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
#    1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# ~/opt/anaconda3/envs/geo_folium/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
#     151                     err = "Could not interpret input '{}'".format(var)
# --> 152                     raise ValueError(err)
#     153
#     154             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Cluster_Labels'
